# %%
# %matplotlib inline
import random
import matplotlib.pyplot as plt

def generate_maze_recursive_backtracking(aX_size, aY_size):
    walls = [[[1,1,1,1] for _ in range(aX_size)] for _ in range(aY_size)]
    visited = [[False for _ in range(aX_size)] for _ in range(aY_size)]
    path = [(0,0)]
    visited[0][0] = True

    while path:
        x, y = path[-1]
        possible = []
        if x > 0 and not visited[y][x-1]:
            possible.append((-1, 0, 0, 2))
        if x < aX_size-1 and not visited[y][x+1]:
            possible.append((1, 0, 2, 0))
        if y > 0 and not visited[y-1][x]:
            possible.append((0, -1, 1, 3))   # nahoru
        if y < aY_size-1 and not visited[y+1][x]:
            possible.append((0, 1, 3, 1))    # dolů

        if possible:
            dx, dy, w1, w2 = random.choice(possible)
            nx, ny = x+dx, y+dy
            walls[y][x][w1] = 0
            walls[ny][nx][w2] = 0
            visited[ny][nx] = True
            path.append((nx, ny))
        else:
            path.pop()
    return walls


def draw_maze(aWalls):
    fig, ax = plt.subplots()
    aY_size = len(aWalls)
    aX_size = len(aWalls[0])
    for y in range(aY_size):
        for x in range(aX_size):
            left, top, right, bottom = aWalls[y][x]
            x0, x1 = x, x+1
            y0, y1 = aY_size - y, aY_size - (y+1)

            if top: ax.plot([x0, x1], [y0, y0], color="black")
            if right: ax.plot([x1, x1], [y0, y1], color="black")
            if bottom: ax.plot([x0, x1], [y1, y1], color="black")
            if left: ax.plot([x0, x0], [y0, y1], color="black")
    ax.set_aspect("equal")
    ax.axis("off")
    plt.title("Prazdne bludiste")
    plt.show()


# --- test ---

maze = generate_maze_recursive_backtracking(60, 60)
draw_maze(maze)
